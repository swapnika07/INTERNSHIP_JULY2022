# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import re
from bs4 import BeautifulSoup

# %%
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
URL ="https://housing.com/in/buy/searches/P4dekofvu5npxonhu_679xe73u28050522"

# %%
# Web scrapper for infinite scrolling page 
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(URL)
time.sleep(2)  # Allow 2 seconds for the web page to open
scroll_pause_time = 1 # You can set your own pause time. My laptop is a bit slow so I use 1 sec
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/98.0.4758.102/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\YASH\.wdm\drivers\chromedriver\win32\98.0.4758.102]
# C:\Users\YASH\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object

# %%
soup = BeautifulSoup(driver.page_source, "html.parser")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d9c02e2e8ea1> in <module>
# ----> 1 soup = BeautifulSoup(driver.page_source, "html.parser")
#
# NameError: name 'driver' is not defined

# %%
mc=soup.find_all('div',class_="css-zrd0bv")

# %%
venture = []
for i in mc:                                              #1
    b = i.find('h3',attrs = {"class":"css-1t3f68z"})
    if b is not None:
        venture.append(b.text)
    else:
        venture.append('NA')
venture[3]

# %%
price = []
for i in mc:       #2
    b = i.find('div',attrs = {"class":"css-18rodr0"})
    if b is not None:
        price.append(b.text)
    else:
        price.append('NA')
print(price[0])

# %%
len(venture),len(price)
type(venture)
type(price)

# %%
Emi = []   #3
for i in mc:
    b = i.find('span',attrs = {"class":"css-nin1gj"})
    if b is not None:
        Emi.append(b.text)
    else:
        Emi.append('NA')

# %%
type(Emi[1])

# %%
marketed = []     #4
for i in mc:
    b = i.find('div',attrs = {"class":"css-1j62xqm"})
    if b is not None:
        marketed.append(b.text)
    else:
        marketed.append('NA')

# %%
type(marketed[5])

# %%
location = []     #5
for i in mc: 
    b = i.find('a',attrs = {"class":"css-16drx2b"})
    if b is not None:
        location.append(b.text)
    else:
        location.append('NA')
len(location)
print(location[1])
type(location)

# %%
beds = []    #6
for i in mc:
    b = i.find('div',attrs = {"class":"css-197fqpq"})
    if b is not None:
        beds.append(b.text)
    else:
        beds.append('NA')

# %%
print(beds[1])

# %%
type(beds)

# %%
possession_date = []    #7
for i in mc:
    b = i.find('div',attrs = {"class":"css-4z3njv"})
    if b is not None:
        possession_date.append(b.text)
    else:
        possession_date.append('NA')

# %%
type(possession_date)

# %%
print(possession_date[2])
# Out:
# Oct, 2022

# %%
possession_date[1010]
# Out:
# '1665 sq.ft'

# %%
Avg = []                      #8
for i in mc:
    b = i.find('div',attrs = {"class":"css-hboir5"})
    if b is not None:
        Avg.append(b.text)
    else:
        Avg.append('NA')
    
len(Avg)
# Out:
# 1675

# %%
Avg[20]
# Out:
# 'Possession StartsJun, 2024Avg. Price₹4.60 K/sq.ft'

# %%
price = list(price)
price
# Out:
# ['₹26.49 L - 42.49 L',
#  '₹6.65 Cr - 7.25 Cr',
#  '₹36.01 L - 52.51 L',
#  '₹1.24 Cr - 1.28 Cr',
#  '₹20.59 L - 47.54 L',
#  '₹89.38 L - 1.66 Cr',
#  '₹30.06 L - 90 L',
#  '₹77.3 L - 95.8 L',
#  '₹2.8 Cr - 3.15 Cr',
#  '₹41.13 L - 91 L',
#  '₹53.55 L - 70.35 L',
#  '₹49.56 L',
#  '₹2.49 Cr',
#  '₹1.2 Cr - 1.61 Cr',
#  '₹2.36 Cr - 3.01 Cr',
#  '₹96 L - 1.4 Cr',
#  '₹35.99 L',
#  '₹86.11 L - 1.47 Cr',
#  '₹1.19 Cr - 3.56 Cr',
#  '₹1.14 Cr - 1.27 Cr',
#  '₹63.71 L - 1.12 Cr',
#  '₹63.76 L - 92.66 L',
#  '₹40.09 L',
#  '₹1.48 Cr - 1.58 Cr',
#  '₹26.39 L - 32.31 L',
#  '₹1.8 Cr - 6.23 Cr',
#  '₹62.02 L - 1.05 Cr',
#  '₹70.28 L - 1.1 Cr',
#  '₹59.39 L - 1.7 Cr',
#  '₹37.28 L - 38 L',
#  '₹1.84 Cr - 3.37 Cr',
#  '₹58.5 L - 91 L',
#  '₹77.84 L - 1.63 Cr',
#  '₹42 L - 43 L',
#  '₹18.0 L - 59.99 L',
#  '₹71.01 L - 86.0 L',
#  '₹94.0 L',
#  '₹81.96 L',
#  '₹1.2 Cr',
#  '₹49.0 L',
#  '₹1.2 Cr',
#  '₹51.0 L',
#  '₹2.5 Cr',
#  '₹18.4 L',
#  '₹12.75 L',
#  '₹59.52 L',
#  '₹20.0 L',
#  '₹13.23 L',
# ...

# %%
df = pd.DataFrame{'venture' : venture, 'price': price, 'Emi': Emi, 'marketed' : marketed, 'location': location ,'no_beds' : beds,'possession_date': possession_date, 'Avg':Avg}
# Out:
#   File "<ipython-input-95-a93c33e380f0>", line 1
#     df = pd.DataFrame{'venture' : venture, 'price': price, 'Emi': Emi, 'marketed' : marketed, 'location': location ,'no_beds' : beds,'possession_date': possession_date, 'Avg':Avg}
#                      ^
# SyntaxError: invalid syntax

# %%
df=pd.DataFrame()

# %%
df['venture']=venture
df['price']=price
df['Emi']=Emi
df['marketed']=marketed
df['location']=location
df['no_beds'] = beds
df['possession_date'] = possession_date
df['Avg'] = Avg
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-1385fb86ccd9> in <module>
# ----> 1 df['venture']=venture
#       2 df['price']=price
#       3 df['Emi']=Emi
#       4 df['marketed']=marketed
#       5 df['location']=location
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
# ...

# %%
df

# %%
df2=df[:1009]

# %%
df2['Avg'][800]

# %%
df['Avg'] = df['Avg'].apply(lambda x : re.search("Price₹.*",x).group())
df['Avg']

# %%
df.to_csv("housing.csv",index = True)

# %%
pwd

# %%
list_1 = soup.find_all('div', attrs = {"class":"css-zrd0bv"})
len(list_1)

# %%
k=soup.find_all('div', attrs = {"class":"css-11nfaq3"})  
len(k)    #bed room and address

# %%
name = []
for i in k:
    if k is None:
        name.append(np.NaN)
    else:
        name.append(i.text)
len(name)

# %%
p = soup.find_all('div',attrs = {"class":"css-18rodr0"})  #price

# %%
price = []
for i in p:
    if p is None:
        price.append(np.NaN)
    else:
        price.append(i.text.strip())
len(price)

# %%
t = soup.find_all('span',attrs = {"class":"css-nin1gj"})  #EMI starting
len(t)

# %%
Emi = []
for i in t:
    Emi.append(i.text)
len(Emi)

# %%
b = soup.find_all('div',attrs = {"class":"css-1ywl03"})
square_foot = []
for i in b:
    if i is not None:
        square_foot.append(i.text)
    else:
        square_foot.append('NA')

# %%
len(square_foot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-1a02c2acede7> in <module>
# ----> 1 len(square_foot)
#
# NameError: name 'square_foot' is not defined

# %%
a = soup.find_all('div',attrs = {"class":"css-4z3njv"})       #Sft and price for sft
a
len(a)

# %%
f = soup.find_all('div',attrs = {"class":"css-kjafn5"})     #Description
description = []
for i in f:
    j=i.find('div',class_="css-nqm4eq")
    if j is not None:
        description.append(j.text)
    else:
        description.append('NA')

# %%
len(description)

# %%
c = soup.find_all('div',attrs = {"class":"css-wni7av"})
contact = []
for i in c:
    j = i.find('a',class_="css-0")
    if j is not None:
        contact.append(j.text)
    else:
        contact.append('NA')

# %%
len(contact)

# %%
len(name)

# %%
len(price)

# %%
len(Emi)

# %%
len(description)

# %%
len(square_foot)

# %%
df = pd.DataFrame({'name':name,'price': price,'Emi': Emi,'square_foot': square_foot,'description': description,'contact':contact})
df.head()

# %%
pd.DataFrame(list(df['name'].str.split()))

# %%
df.info()

# %%
name = list(name)    #converting it into beds columns
beds = []      
for i in name:
    beds.append(i[0])

# %%
len(beds)

# %%
name = list(name)    #column for Location
location = []
for i in name:
    location.append(i[23:])
print(len(location))

# %%
len(location)

# %%
Emi = list(Emi)                     #Column for Emi
monthly_emi = []
for i in Emi:
    monthly_emi.append(i[15:])
print(len(monthly_emi))

# %%
df['square_foot']

# %%
df['sqr_ft'] = df['square_foot'].apply(lambda x : re.search('\d+',x).group())
df['sqr_ft']

# %%
df['price_sft'] = df['square_foot'].apply(lambda x : re.search('Price₹.*',x).group())

# %%
price_sft = df['price_sft'].str.replace("Price₹",'')
price_sft

# %%
df1 =  pd.DataFrame({'beds':beds,'location': location, 'Price_sft': price_sft})
df1

# %%
df.drop(['name','square_foot','Emi','price_sft'],axis = 1,inplace = True)

# %%
df['description'][0]

# %%
df['description'][2000]

# %%
 df['description'].apply(lambda x : re.search(r'floor.\d+',x).group())

# %%
re2=re.compile(r'floor.\d+')

# %%
re2=re.compile(r'floor.\d+')
floor = []
for i in  df['description']:
    if 'floor' in i.lower():
        floor.append(''.join(re2.findall(i)))
    else:
        floor.append('NA')
print(len(floor))

# %%
re2=re.compile(r'(\w+)-facing')
facing = []
for i in  df['description']:
    if 'facing' in i.lower():
        facing.append(''.join(re2.findall(i)))
    else:
        facing.append('NA')
print(len(facing))

# %%
df1['facing'] = facing
df1['floor']= floor
df1

# %%
df['description'][200]

# %%
df1['facing'][198]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-e020a335664a> in <module>
# ----> 1 df1['facing'][198]
#
# NameError: name 'df1' is not defined

# %%
location = df1['location'].str.replace(", Hyderabad"," ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-b026f9dad6cd> in <module>
# ----> 1 location = df1['location'].str.replace(", Hyderabad"," ")
#
# NameError: name 'df1' is not defined

# %%
df1['Location'] = location
df1.drop(['location'],axis = 1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-29b92c8a52cc> in <module>
# ----> 1 df1['Location'] = location
#       2 df1.drop(['location'],axis = 1,inplace = True)
#
# NameError: name 'df1' is not defined

# %%
df.drop(['description'],axis = 1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-4c51aed53c08> in <module>
# ----> 1 df.drop(['description'],axis = 1,inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df
# Out:
#                                   venture               price  \
# 0     Provident Manhattan Pods And Condos  ₹26.49 L - 42.49 L
# 1               Giridhari Prospera County  ₹6.65 Cr - 7.25 Cr
# 2                      Aspirealty Advaith  ₹36.01 L - 52.51 L
# 3                      Om Sree Brilliance  ₹1.24 Cr - 1.28 Cr
# 4                            Sree Nivasam  ₹20.59 L - 47.54 L
# ...                                   ...                 ...
# 1661                                   NA             ₹69.3 L
# 1662                                   NA            ₹61.03 L
# 1663                                   NA             ₹52.5 L
# 1664                                   NA             ₹57.5 L
# 1665                                   NA            ₹49.94 L
#
#                            Emi                             marketed  \
# 0       EMI starts at ₹14.03 K        By  Provident Housing Limited
# 1     EMI starts at ₹3.30 Lacs          By  Giridhari Constructions
# ...

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-6a861a8b3f1a> in <module>
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-bce70adc7f6c> in <module>
# ----> 1 housing = pd.concat([df,df1],axis = 1)
#       2 housing
#
# NameError: name 'df1' is not defined

# %%
housing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-157ed7dade7e> in <module>
# ----> 1 housing
#
# NameError: name 'housing' is not defined
