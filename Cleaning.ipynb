# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df=pd.read_csv("House.csv")

# %%
df
# Out:
#      Unnamed: 0                                           location  \
# 0             0          Rajiv Gandhi Nagar, Gachibowli, Hyderabad
# 1             1  Golf Edge,Financial District, Nanakaramguda,Hy...
# 2             2                     Mega Hills, Madhapur,Hyderabad
# 3             3  Kondapur sri ram nagar colony,Kondapur, Hyderabad
# 4             4                  Police Colony, Kondapur,Hyderabad
# ..          ...                                                ...
# 525         525  Lodha Meridian,KPHB Phase 15, Kukatpally,Hyder...
# 526         526  Malaysian Township,KPHB Phase 15, Kukatpally,H...
# 527         527  Malyasian TownShip,KPHB Phase 15, Kukatpally,H...
# 528         528             Madava RESIDENCY,Kukatpally, Hyderabad
# 529         529  Prajay Megapolis,KPHB Phase 15, Kukatpally,Hyd...
#
#                                            description   price  no_beds  \
# 0    Our fees only Rs. 10K + GST for an apartment i...  25,000        3
# ...

# %%
df['price'] = df['price'].str.replace(',',"")

# %%
df = df.drop(labels =0,axis = 0)

# %%
df
# Out:
#      Unnamed: 0                                           location  \
# 1             1  Golf Edge,Financial District, Nanakaramguda,Hy...
# 2             2                     Mega Hills, Madhapur,Hyderabad
# 3             3  Kondapur sri ram nagar colony,Kondapur, Hyderabad
# 4             4                  Police Colony, Kondapur,Hyderabad
# 5             5  Prime professional consultance,Gachibowli, Hyd...
# ..          ...                                                ...
# 525         525  Lodha Meridian,KPHB Phase 15, Kukatpally,Hyder...
# 526         526  Malaysian Township,KPHB Phase 15, Kukatpally,H...
# 527         527  Malyasian TownShip,KPHB Phase 15, Kukatpally,H...
# 528         528             Madava RESIDENCY,Kukatpally, Hyderabad
# 529         529  Prajay Megapolis,KPHB Phase 15, Kukatpally,Hyd...
#
#                                            description  price  no_beds  \
# 1    Our fees only Rs. 10K + GST for an apartment i...  44000        3
# ...

# %%
df
# Out:
#      Unnamed: 0                                           location  \
# 1             1  Golf Edge,Financial District, Nanakaramguda,Hy...
# 2             2                     Mega Hills, Madhapur,Hyderabad
# 3             3  Kondapur sri ram nagar colony,Kondapur, Hyderabad
# 4             4                  Police Colony, Kondapur,Hyderabad
# 5             5  Prime professional consultance,Gachibowli, Hyd...
# ..          ...                                                ...
# 525         525  Lodha Meridian,KPHB Phase 15, Kukatpally,Hyder...
# 526         526  Malaysian Township,KPHB Phase 15, Kukatpally,H...
# 527         527  Malyasian TownShip,KPHB Phase 15, Kukatpally,H...
# 528         528             Madava RESIDENCY,Kukatpally, Hyderabad
# 529         529  Prajay Megapolis,KPHB Phase 15, Kukatpally,Hyd...
#
#                                            description  price  no_beds  \
# 1    Our fees only Rs. 10K + GST for an apartment i...  44000        3
# ...

# %%
df['Type'].value_counts()
# Out:
# Flat           397
# Independent    116
# Villa           16
# Name: Type, dtype: int64

# %%
df['Furnishing'] = df['Furnishing'].str.replace(']',"")

# %%
df['Furnishing'] = df['Furnishing'].str.replace('[',"")

# %%
df['Furnishing'] = df['Furnishing'].str.replace(" ","")

# %%
df['Furnishing'].value_counts()
# Out:
# SemiFurnished     367
# FullyFurnished     85
# Unfurnished        77
# Name: Furnishing, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 529 entries, 1 to 529
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   529 non-null    int64
#  1   location     529 non-null    object
#  2   description  515 non-null    object
#  3   price        529 non-null    object
#  4   no_beds      529 non-null    int64
#  5   square_foot  529 non-null    int64
#  6   Type         529 non-null    object
#  7   Furnishing   529 non-null    object
#  8   building     529 non-null    object
#  9   place        529 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 45.5+ KB

# %%
df.drop(['location'],axis = 'columns',inplace = True)

# %%
df['description']
# Out:
# 1      Our fees only Rs. 10K + GST for an apartment i...
# 2      3bhk brand new  semi Furnished flat  available...
# 3      This is a modern and stylish home available fo...
# 4      It is a beautiful Apartment. Semi-furnished pr...
# 5      2BHK flat  in gachibowli near by Gachibowli fu...
#                              ...
# 525    Our fees only Rs. 10K + GST for an apartment i...
# 526    Our fees only Rs. 10K + GST for an apartment i...
# 527    Our fees only Rs. 10K + GST for an apartment i...
# 528    Our fees only Rs. 10K + GST for an apartment i...
# 529    Our fees only Rs. 10K + GST for an apartment i...
# Name: description, Length: 529, dtype: object

# %%
re2=re.compile(r'(\d*).bath')
bath= []
for i in  df['description']:
    if 'bath' in str(i).lower():
        bath.append(''.join(re2.findall(i)))
    else:
        bath.append('NA')
print(len(bath))
# Out:
# 529

# %%
print(bath)
# Out:
# ['NA', 'NA', '2', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2', '2', 'NA', 'NA', 'NA', 'NA', 'NA', '2', 'NA', 'NA', 'NA', 'NA', 'NA', '', 'NA', '', '3', 'NA', '4', '1', 'NA', 'NA', 'NA', '3', 'NA', 'NA', '3', '2', 'NA', 'NA', 'NA', 'NA', '1', '', 'NA', '2', 'NA', '3', 'NA', 'NA', 'NA', '3', '', '', '4', '', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2', 'NA', '2', 'NA', 'NA', '', 'NA', '1', 'NA', 'NA', 'NA', '2', '2', 'NA', 'NA', 'NA', '3', 'NA', 'NA', '2', '', 'NA', '2', 'NA', 'NA', '3', 'NA', '2', 'NA', 'NA', 'NA', '1', 'NA', 'NA', 'NA', '3', '3', '', 'NA', 'NA', '1', 'NA', 'NA', '1', 'NA', 'NA', 'NA', 'NA', '4', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '1', 'NA', 'NA', '2', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2', 'NA', 'NA', '3', 'NA', 'NA', 'NA', 'NA', 'NA', '2', 'NA', 'NA', '2', 'NA', 'NA', 'NA', 'NA', 'NA', '3', '', 'NA', '3', 'NA', '3', 'NA', '1', '2', '5', 'NA', 'NA', '4', 'NA', '', '1', '2', '3', '2', '3', 
# ...

# %%
df['bath'] = bath

# %%
df['bath']
# Out:
# 1      NA
# 2      NA
# 3       2
# 4      NA
# 5      NA
#        ..
# 525    NA
# 526    NA
# 527    NA
# 528    NA
# 529    NA
# Name: bath, Length: 529, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 529 entries, 1 to 529
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   529 non-null    int64
#  1   description  515 non-null    object
#  2   price        529 non-null    object
#  3   no_beds      529 non-null    int64
#  4   square_foot  529 non-null    int64
#  5   Type         529 non-null    object
#  6   Furnishing   529 non-null    object
#  7   building     529 non-null    object
#  8   place        529 non-null    object
#  9   bath         529 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 65.5+ KB

# %%
re2=re.compile(r'(\d*).floor')
floor = []
for i in  df['description']:
    if 'floor' in str(i).lower():
        floor.append(''.join(re2.findall(i)))
    else:
        floor.append('NA')
print(len(floor))
# Out:
# 529

# %%
df['description'][25]
# Out:
# 'Check out this Semi-furnished property available at an economical rent. Rent a 3 BHK Apartment in this landmark location. The property is on floor number 1 in a building with 5 floors. Spacious property available for rent only in Manikonda. Mid-segment homes for rent now in Hyderabad. Fee of Rs 42000 for security charges apply. Amount of Rs 22000 to be paid as rent. This 1400 sq ft built up area property is available on rent at an affordable price. Big and spacious home available for rent, check out these 31 photos. This property has 2 big bath. Property on rent near metro is available from 20...Read more'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 529 entries, 1 to 529
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   529 non-null    int64
#  1   description  515 non-null    object
#  2   price        529 non-null    object
#  3   no_beds      529 non-null    int64
#  4   square_foot  529 non-null    int64
#  5   Type         529 non-null    object
#  6   Furnishing   529 non-null    object
#  7   building     529 non-null    object
#  8   place        529 non-null    object
#  9   bath         529 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 65.5+ KB

# %%
is_NaN = df.isnull()
k = is_NaN.any(axis=1)

# %%
df.drop(['Unnamed: 0','description'],axis = 1, inplace = True)

# %%
df['floor'] = floor

# %%
df
# Out:
#      price  no_beds  square_foot  Type      Furnishing  \
# 1    44000        3         2000  Flat  FullyFurnished
# 2    28000        3         2000  Flat   SemiFurnished
# 3    21000        2         1300  Flat  FullyFurnished
# 4    17000        2         1100  Flat   SemiFurnished
# 5    21000        2         1050  Flat  FullyFurnished
# ..     ...      ...          ...   ...             ...
# 525  34000        3         2000  Flat   SemiFurnished
# 526  24000        3         1500  Flat  FullyFurnished
# 527  23000        3         1008  Flat   SemiFurnished
# 528  24000        3         1152  Flat   SemiFurnished
# 529  29000        3         1740  Flat   SemiFurnished
#
#                            building           place bath floor
# 1                         Golf Edge   Nanakaramguda   NA    NA
# 2                        Mega Hills        Madhapur   NA    NA
# 3     Kondapur sri ram nagar colony        Kondapur    2     3
# ...

# %%
df['price'] = pd.to_numeric(df['price'])

# %%
df['price'].sum()
# Out:
# 14359835

# %%
df['no_beds'].value_counts()
# Out:
# 3     272
# 2     172
# 1      57
# 4      19
# 5       6
# 6       2
# 10      1
# Name: no_beds, dtype: int64

# %%
k = df[df['place'] == ' Kondapur']
k
# Out:
#      price  no_beds  square_foot         Type      Furnishing  \
# 3    21000        2         1300         Flat  FullyFurnished
# 4    17000        2         1100         Flat   SemiFurnished
# 12   14000        2         1250         Flat   SemiFurnished
# 13   15000        2         1050         Flat   SemiFurnished
# 18   15500        2         1250         Flat   SemiFurnished
# 19   15000        2         1050         Flat   SemiFurnished
# 21   30000        3         2335         Flat   SemiFurnished
# 28   18000        3         1650         Flat     Unfurnished
# 60   18000        2         1240         Flat   SemiFurnished
# 62   25000        3         1550         Flat   SemiFurnished
# 67   18000        2         1300         Flat   SemiFurnished
# 90   21000        3         1630         Flat     Unfurnished
# 98    6999        1          800         Flat     Unfurnished
# 108  17000        2         1300         Flat   SemiFurnished
# ...

# %%
df['place'].value_counts()
# Out:
#  Kukatpally       56
#  Nanakaramguda    50
#  Madhapur         48
#  Hitech City      27
#  Kondapur         27
#                   ..
#  Siddipet          1
#  Musheerabad       1
#  Manchirevula      1
#  Hyderguda         1
#  Adibatla          1
# Name: place, Length: 122, dtype: int64

# %%
df['bath'] = df['bath'].replace("NA",2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 529 entries, 1 to 529
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        529 non-null    int64
#  1   no_beds      529 non-null    int64
#  2   square_foot  529 non-null    int64
#  3   Type         529 non-null    object
#  4   Furnishing   529 non-null    object
#  5   building     529 non-null    object
#  6   place        529 non-null    object
#  7   bath         529 non-null    object
#  8   floor        529 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 61.3+ KB

# %%
df['floor'] = df['floor'].replace("3516",5)

# %%
df['floor'].value_counts()
# Out:
# NA     320
# 5       58
# 4       30
# 3       27
#         22
# 2       17
# 1       13
# 6       12
# 14       3
# 25       2
# 31       2
# 9        2
# 13       2
# 32       2
# 55       2
# 23       1
# 5        1
# 29       1
# 133      1
# 34       1
# 24       1
# 10       1
# 620      1
# 11       1
# 51       1
# 18       1
# 19       1
# 7        1
# 33       1
# 42       1
# Name: floor, dtype: int64

# %%
df['bath'] = df['bath'].replace("NA",2)

# %%
df['floor'] = df['floor'].replace("NA",int(5))

# %%
df['floor']
# Out:
# 1      5
# 2      5
# 3      3
# 4      4
# 5      5
#       ..
# 525    5
# 526    5
# 527    5
# 528    5
# 529    5
# Name: floor, Length: 529, dtype: object

# %%
df['bath']=df['bath'].fillna(2)

# %%
df['bath'].str.replace('',"")
df['bath'].value_counts()
# Out:
# 2    388
# 2     60
# 3     31
#       22
# 1     19
# 4      6
# 5      2
# 6      1
# Name: bath, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 529 entries, 1 to 529
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        529 non-null    int64
#  1   no_beds      529 non-null    int64
#  2   square_foot  529 non-null    int64
#  3   Type         529 non-null    object
#  4   Furnishing   529 non-null    object
#  5   building     529 non-null    object
#  6   place        529 non-null    object
#  7   bath         529 non-null    object
#  8   floor        529 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 61.3+ KB

# %%
df['place'].isnull().sum()
# Out:
# 0

# %%
df['bath'].replace(' ',1)
# Out:
# 1      2
# 2      2
# 3      2
# 4      2
# 5      2
#       ..
# 525    2
# 526    2
# 527    2
# 528    2
# 529    2
# Name: bath, Length: 529, dtype: object

# %%
df.describe()
# Out:
#               price     no_beds   square_foot
# count    529.000000  529.000000    529.000000
# mean   27145.245747    2.542533   1612.319471
# std    16680.538467    0.869619    828.524020
# min     5000.000000    1.000000    150.000000
# 25%    15000.000000    2.000000   1150.000000
# 50%    23000.000000    3.000000   1500.000000
# 75%    35000.000000    3.000000   2000.000000
# max    85000.000000   10.000000  11000.000000

# %%
df['floor'].value_counts()
# Out:
# 5      321
# 5       58
# 4       30
# 3       27
#         22
# 2       17
# 1       13
# 6       12
# 14       3
# 13       2
# 32       2
# 9        2
# 31       2
# 25       2
# 55       2
# 23       1
# 29       1
# 133      1
# 34       1
# 24       1
# 10       1
# 620      1
# 11       1
# 51       1
# 18       1
# 19       1
# 7        1
# 33       1
# 42       1
# Name: floor, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 6

# %%
df['Type'].value_counts()
# Out:
# Flat           397
# Independent    116
# Villa           16
# Name: Type, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 529 entries, 1 to 529
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        529 non-null    int64
#  1   no_beds      529 non-null    int64
#  2   square_foot  529 non-null    int64
#  3   Type         529 non-null    object
#  4   Furnishing   529 non-null    object
#  5   building     529 non-null    object
#  6   place        529 non-null    object
#  7   bath         529 non-null    object
#  8   floor        529 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 61.3+ KB

# %%
df['bath'] = pd.to_numeric(df['bath'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 529 entries, 1 to 529
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        529 non-null    int64
#  1   no_beds      529 non-null    int64
#  2   square_foot  529 non-null    int64
#  3   Type         529 non-null    object
#  4   Furnishing   529 non-null    object
#  5   building     529 non-null    object
#  6   place        529 non-null    object
#  7   bath         507 non-null    float64
#  8   floor        529 non-null    object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 61.3+ KB

# %%
df['place'].fillna("kondapur",inplace = True)

# %%
df['place'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Observations
#
# ## dataset is ready for exploring, and it does'nt consist of null values.

# %% [markdown]
# # Univaraiate plotting

# %% [markdown]
# df.info()

# %%
df['floor'] = pd.to_numeric(df['floor'])

# %% [markdown]
# # Plotting between type and no of beds

# %%
plt.figure(figsize = (7,7))        #for 
plots = sns.countplot(df['Furnishing'])
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=12, xytext=(0, 7),
                   textcoords='offset points')
plt.show()
plt.savefig("furnishing.jpg")

# %% [markdown]
# + In the above we noticed that semi furnished flats are high.. and fully, unfurnished are some what equal

# %%
sns.set(rc={'figure.figsize':(7,7)})
sns.set(font_scale = 1.5)
sns.stripplot(y= df['price'])
plt.savefig("output.jpg")

# %% [markdown]
#  + Here from the above plot we noticed that price for rent in hyderabad is in at 15k to 25k...

# %%
plt.figure(figsize = (8,7))
sns.distplot(df['no_beds'])

# %% [markdown]
# + From the above we noticed that their are more number of 3beds compared to 2.

# %% [markdown]
# + Univaraite box plot on square_foot

# %%
plt.boxplot(df['square_foot'][520:])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22d4b6e8c48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22d4b6e8dc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22d4b62b408>],
#  'medians': [<matplotlib.lines.Line2D at 0x22d4b6ecdc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22d4b6ece48>],
#  'means': []}

# %% [markdown]
# + Extreme datapoints that is away most of the data...

# %%
plots=sns.countplot(df['Type'])
plt.title("Distribution of Types of Houses")
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')

# %% [markdown]
# # heat map shows the correlation between numerical variables..
# ### we dont need to select..
# correlation is good when the value lies between -1 to +1 with this we understood that square and beds are much related price is also much related with beds and square foot
# ...

# %% [markdown]
# sns.heatmap(df.corr(),annot = True)    #we understand the  no_beds and square foot are much corelated,price and square is related

# %%
for i in df['square_foot']:
    print(i)
# Out:
# 2000
# 2000
# 1300
# 1100
# 1050
# 1600
# 2800
# 1742
# 2200
# 2000
# 1210
# 1250
# 1050
# 1200
# 1900
# 1900
# 1210
# 1250
# 1050
# 1200
# 2335
# 1800
# 2000
# 1655
# 1400
# 1780
# 1250
# 1650
# 1800
# 3000
# 1384
# 1781
# 900
# 1100
# 1450
# 988
# 1100
# 1430
# 2000
# 800
# 1875
# 1500
# 1650
# 150
# 1300
# 1550
# 1290
# 3680
# 1742
# 997
# 500
# 2225
# 1400
# 400
# 1170
# 2023
# 1000
# 950
# 1400
# 1240
# 1370
# 1550
# 1900
# 800
# 1200
# 1100
# 1300
# 1250
# 1000
# 1080
# 1200
# 1800
# 1800
# 500
# 1500
# 1503
# 1635
# 4500
# 600
# 2500
# 1740
# 500
# 1500
# 5155
# 850
# 1200
# 1300
# 252
# 1100
# 1630
# 700
# 2000
# 1300
# 760
# 300
# 1900
# 2000
# 800
# 460
# 1154
# 500
# 1600
# 2000
# 1000
# 1450
# 1200
# 580
# 1300
# 1400
# 750
# 664
# 1250
# 390
# 750
# 2780
# 1960
# 3100
# 1000
# 1200
# 1640
# 1358
# 500
# 1180
# 750
# 800
# 1200
# 1010
# 1650
# 600
# 2800
# 700
# 650
# 1600
# 900
# 1100
# 1200
# 1100
# 750
# 1250
# 1250
# 1050
# 550
# 1350
# 2300
# 1350
# 1452
# 1200
# ...

# %%
#plt.bar(df['Type'],df['no_beds'],color = 'lightblue')
plt.bar(df['Type'],df['square_foot'],color = 'blue')   #their is some uncertainity in the data #to get the same chart in horizontal give barh
plt.xlabel('Type of Houses');

# %% [markdown]
# # plotting of price in Hyderabad

# %%
plt.figure(figsize = (10,10))
plt.hist(df['price'],histtype ='bar',edgecolor='black',bins = 20)      ##WE understood from the above graph it shows that most of the price of the is around 18k
plt.title("Price vs No of Houses")
plt.xlabel('price')
plt.ylabel('no of houses for rent')
plt.show()

# %% [markdown]
# # Pie chart

# %%
plt.figure(figsize = (10,8))
label = ["Flat","Independent","Villa"]
plt.pie(x = df['Type'].value_counts(),labels = label,startangle =45,autopct='%1.1f%%',shadow = True )
plt.show()

# %%
sns.distplot(df['price'],kde = True)  
plt.xlabel("Price")
plt.ylabel('Density')
plt.title("Distribution of Rental Price")
# Out:
# Text(0.5, 1.0, 'Distribution of Rental Price')

# %% [markdown]
# #  as we can see the house for rent are more in hyderabad at 18k to 20k

# %% [markdown]
# # Bivariate Analysis - It means using two variables

# %%
df1 = df[(df['no_beds']== 3)&(df['price'])]
df1
# Out:
#      price  no_beds  square_foot  Type      Furnishing  \
# 154  48001        3         1740  Flat   SemiFurnished
# 362  42001        3         1345  Flat   SemiFurnished
# 407  50015        3         1700  Flat  FullyFurnished
# 409  45015        3         2300  Flat   SemiFurnished
#
#                               building           place  bath  floor
# 154                Prestige Ivy League       Kothaguda   2.0    5.0
# 362               Vajra Jasmine County   Nanakaramguda   2.0    5.0
# 407               Bluestone Buckingham        Madhapur   2.0    5.0
# 409  Vaishnavi Fresh Living Apartments        Madhapur   2.0    5.0

# %%
sns.barplot(x = df['Furnishing'],y=df['price'],data=df)
sns.countplot(x=df['Furnishing'],data=df)
plt.xlabel('Type of the Houses')
plt.ylabel('Price of the House for Rent')
plt.title("Distribution of Furnishing and price")
# Out:
# Text(0.5, 1.0, 'Distribution of Furnishing and price')

# %% [markdown]
# ### From the above graph we can understand that the fully furnished house costs more compaired to semi and unfurnished...

# %%
sns.stripplot(df['no_beds'], y = df['price'], data=df)
plt.xlabel("No of beds")
plt.ylabel("Rent of the house")
plt.title("STRIP PLOT FOR RENT VS NO_OF_BEDS")
# Out:
# Text(0.5, 1.0, 'STRIP PLOT FOR RENT VS NO_OF_BEDS')

# %% [markdown]
# From the above graph we understood that there are more number of semi furnished houses in hyderabad location...

# %%
sns.violinplot(x=df['Furnishing'], y=df['no_beds'], data=df,palette='rainbow')
plt.xlabel("Furnishing")
plt.ylabel("Number of beds")
plt.title("FURNISHING VS NUMBER_OF_BEDS")
# Out:
# Text(0.5, 1.0, 'FURNISHING VS NUMBER_OF_BEDS')

# %%
df[(df['Type'] == 'Villa')&(df['price'] >15000)]
# Out:
#      price  no_beds  square_foot   Type      Furnishing  \
# 7    80000        3         2800  Villa  FullyFurnished
# 30   25000        5         3000  Villa   SemiFurnished
# 159  20000        3         2100  Villa   SemiFurnished
# 168  85000        4         3600  Villa   SemiFurnished
# 170  50000        5         3500  Villa     Unfurnished
# 184  20000        3         2200  Villa   SemiFurnished
# 223  60000        4         3430  Villa   SemiFurnished
# 232  65000        5         4000  Villa  FullyFurnished
# 235  30000        3         3000  Villa     Unfurnished
# 279  19000        3         1900  Villa   SemiFurnished
# 286  49000        3         3431  Villa   SemiFurnished
# 305  25000        3         3000  Villa  FullyFurnished
# 328  40000        4         3100  Villa   SemiFurnished
# 381  74000        5         4800  Villa   SemiFurnished
# 382  54000        4         4500  Villa   SemiFurnished
# 461  35002        3         3200  Villa  FullyFurnished
#
# ...

# %% [markdown]
# # seaborn pairplot

# %%
plt.figure(figsize = (10,8))    #pairplot shows the all the numeric values representation and the graph between
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.lineplot(x = df["no_beds"],y = df['price'],hue = df['place'][0:20],data = df)

# %%
df.describe()
# Out:
#               price     no_beds   square_foot        bath       floor
# count    529.000000  529.000000    529.000000  507.000000  507.000000
# mean   27145.245747    2.542533   1612.319471    2.067061    7.181460
# std    16680.538467    0.869619    828.524020    0.457092   28.413982
# min     5000.000000    1.000000    150.000000    1.000000    1.000000
# 25%    15000.000000    2.000000   1150.000000    2.000000    5.000000
# 50%    23000.000000    3.000000   1500.000000    2.000000    5.000000
# 75%    35000.000000    3.000000   2000.000000    2.000000    5.000000
# max    85000.000000   10.000000  11000.000000    6.000000  620.000000

# %%
plt.figure(figsize = (20,8))
sns.lineplot(df['place'][0:20], y = df['price'])

# %% [markdown]
# # Scatter plot
# ## it represents the relationship between two variables so here in our scenario we are checking the price with sft and furnishing,, we can see its linear and positive relation between datapoints

# %%
plt.figure(figsize = (8,8))
sns.scatterplot(data=df,x=df["square_foot"], y=df['price'],hue = df['Furnishing'],sizes = (100,200))
plt.title("Scatter plot for square foot and price")
plt.show()

# %%
df['price'].describe()
# Out:
# count      529.000000
# mean     27145.245747
# std      16680.538467
# min       5000.000000
# 25%      15000.000000
# 50%      23000.000000
# 75%      35000.000000
# max      85000.000000
# Name: price, dtype: float64

# %%
df.describe()       #describe will always give  central tendency of numerical values
# Out:
#               price     no_beds   square_foot        bath       floor
# count    529.000000  529.000000    529.000000  507.000000  507.000000
# mean   27145.245747    2.542533   1612.319471    2.067061    7.181460
# std    16680.538467    0.869619    828.524020    0.457092   28.413982
# min     5000.000000    1.000000    150.000000    1.000000    1.000000
# 25%    15000.000000    2.000000   1150.000000    2.000000    5.000000
# 50%    23000.000000    3.000000   1500.000000    2.000000    5.000000
# 75%    35000.000000    3.000000   2000.000000    2.000000    5.000000
# max    85000.000000   10.000000  11000.000000    6.000000  620.000000

# %%
sns.distplot(df['price'],kde = True)       #Observation is dist plot will always consider numerical columns  
                                            #KDE - Kernel density

# %%
plt.figure(figsize = (10,8))
sns.boxplot(df['Furnishing'],y = df['price'],hue = df['Type'],data = df)
plt.title("BOX plot for Furnishing and price")
# Out:
# Text(0.5, 1.0, 'BOX plot for Furnishing and price')

# %%
plt.figure(figsize = (10,8))
sns.boxplot(df['Furnishing'], y=df['price'],  data=df)
sns.swarmplot(df['Furnishing'],y = df['price'],data = df,color =" .25")
plt.show()

# %%
df['Type'].unique()
# Out:
# array(['Flat', 'Independent', 'Villa'], dtype=object)

# %%
df3 = df.groupby(['place','price']).sum()
df3
# Out:
#                     no_beds  square_foot  bath  floor
# place        price
#  Abids       13000        2          800   2.0    5.0
#  Adibatla    7000         2         1192   0.0    5.0
#  Amberpet    16000        2         1100   2.0    5.0
#              22000        3         1560   2.0    5.0
#  Ameerpet    5000         1          460   2.0    4.0
# ...                     ...          ...   ...    ...
#  Yousufguda  8500         1          600   2.0    0.0
#              9000         1          450   0.0    5.0
#              60000        3         2200   2.0    5.0
#  Zamistanpur 10000        2         1000   2.0    5.0
#              25000        3         1600   3.0    5.0
#
# [421 rows x 4 columns]

# %%
#Syntax: DataFrame.nlargest(n, columns, keep='first')
df5 = df.nlargest(20,['price','no_beds'])
#large5 = data.nlargest(5, "Salary")
sns.barplot(x = df5['price'],y = df5['place'],data = df5)
plt.title("Top 10 highest rented places in Hyderabad")
# Out:
# Text(0.5, 1.0, 'Top 10 highest rented places in Hyderabad')

# %%
df6 = df.nsmallest(15,['price','no_beds'])
df6
# Out:
#      price  no_beds  square_foot         Type     Furnishing  \
# 99    5000        1          460         Flat    Unfurnished
# 113   5000        1          390  Independent  SemiFurnished
# 327   5300        1          500  Independent  SemiFurnished
# 224   5500        1         1500         Flat    Unfurnished
# 231   5500        1          600  Independent    Unfurnished
# 205   6000        1          150         Flat  SemiFurnished
# 326   6000        1          500  Independent    Unfurnished
# 331   6000        1          800         Flat    Unfurnished
# 342   6000        2          900         Flat  SemiFurnished
# 91    6200        1          700         Flat    Unfurnished
# 299   6500        1          220  Independent  SemiFurnished
# 308   6500        1          450         Flat  SemiFurnished
# 288   6500        2          700  Independent  SemiFurnished
# 98    6999        1          800         Flat    Unfurnished
# ...

# %%
sns.barplot(x = df6['price'],y = df6['place'],data = df6)
plt.xlabel("Lowest price range")
plt.ylabel("Location")
plt.title("Distribution for lowest price")
# Out:
# Text(0.5, 1.0, 'Distribution for lowest price')

# %%
df7 = df[(df['price'] <=15000)&(df["no_beds"] <=3)]
df7.drop(['bath','floor','building'],axis = "columns")
df7
# Out:
#      price  no_beds  square_foot         Type      Furnishing  \
# 12   14000        2         1250         Flat   SemiFurnished
# 13   15000        2         1050         Flat   SemiFurnished
# 19   15000        2         1050         Flat   SemiFurnished
# 20   15000        3         1200         Flat     Unfurnished
# 27   14500        2         1250         Flat   SemiFurnished
# ..     ...      ...          ...          ...             ...
# 348   7000        2          650  Independent   SemiFurnished
# 350  12000        2         1700  Independent   SemiFurnished
# 420  15000        3         1200         Flat  FullyFurnished
# 427  15000        3         1200         Flat     Unfurnished
# 463  15000        2         1900         Flat   SemiFurnished
#
#                                     building         place  bath  floor
# 12   Kondapur Raghavendra Colony Rto Office       Kondapur   2.0   25.0
# 13                             Police Colony      Kondapur   2.0    5.0
# ...

# %%
sns.barplot(df7['price'],df7['Furnishing'],hue = df7["no_beds"])
plt.xlabel("Price Range")
plt.ylabel("Type of the houses available")
plt.show()

# %%
df3 = df.groupby('Type')['Furnishing'].value_counts()
df3
# Out:
# Type         Furnishing
# Flat         SemiFurnished     294
#              FullyFurnished     67
#              Unfurnished        36
# Independent  SemiFurnished      63
#              Unfurnished        39
#              FullyFurnished     14
# Villa        SemiFurnished      10
#              FullyFurnished      4
#              Unfurnished         2
# Name: Furnishing, dtype: int64

# %%
df3 = df['place'].value_counts()
df3 = dict(df3)
df3
# Out:
# {' Kukatpally': 56,
#  ' Nanakaramguda': 50,
#  ' Madhapur': 48,
#  ' Hitech City': 27,
#  ' Kondapur': 27,
#  ' Gachibowli': 14,
#  ' Manikonda': 13,
#  ' Puppalaguda': 13,
#  ' Serilingampally': 11,
#  ' Begumpet': 10,
#  ' Banjara Hills': 10,
#  ' Chandanagar': 9,
#  ' Toli Chowki': 9,
#  ' Ameerpet': 8,
#  ' Miyapur': 7,
#  ' Kothapet': 6,
#  ' Mehdipatnam': 6,
#  ' Kothaguda': 6,
#  ' Attapur': 5,
#  ' Bandlaguda Jagir': 5,
#  ' Sainikpuri': 5,
#  ' Krishna Reddy Pet': 4,
#  ' Yousufguda': 4,
#  ' Hafeezpet': 4,
#  ' Himayath Nagar': 4,
#  ' Narsingi': 4,
#  ' Bachupally': 4,
#  ' Kapra': 4,
#  ' Lingampally': 4,
#  ' Vanasthalipuram': 4,
#  ' Kismatpur': 4,
#  ' Uppal': 4,
#  ' Nagole': 3,
#  ' Rai Durg': 3,
#  ' Masab Tank': 3,
#  ' Gaddi Annaram': 3,
#  ' Shaikpet': 3,
#  ' Nizampet': 3,
#  ' Boduppal': 3,
#  ' Old Bowenpally': 3,
#  ' Jeedimetla': 3,
#  ' Moula Ali': 3,
#  ' Jubilee Hills': 3,
#  ' Meerpet': 3,
#  ' Upparpally': 3,
#  ' Bharat Heavy Electricals Limited': 2,
# ...

# %%
plt.figure(figsize = (10,10))
sns.barplot(y = list(df3.keys())[0:20], 
             x= list(df3.values())[0:20])
plt.title("Locations for Rent")
plt.ylabel("Top 20 places")
plt.xlabel("No of Houses for rent")
# Out:
# Text(0.5, 0, 'No of Houses for rent')

# %% [markdown]
# ### From the above graph we can identify that highest for rent registered is kukatpally and the lowest if for badlaguda from the above graph
